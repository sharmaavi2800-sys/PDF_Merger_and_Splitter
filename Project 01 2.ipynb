# %%
pip install PyPDF2 pdfplumber
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PyPDF2 import PdfMerger, PdfReader, PdfWriter
import pdfplumber

# %%
 def merge_pdfs(pdf_list, output_name):
    merger = PdfMerger()
    
    for pdf in pdf_list:
        merger.append(pdf)
        
    merger.write(output_name)
    merger.close()
print("PDF files merged successfully")
# Out:
# PDF files merged successfully

# %%
def split_pdf(pdf_file):
    reader = PdfReader(pdf_file)
    total_pages = len(reader.pages)
    
    for i in range(total_pages):
        writer = PdfWriter()
        writer.add_page(reader.pages[i])
        
        output_name = f"page_{i+1}.pdf"
        with open(output_name, "wb") as f:
            writer.write(f)
    
    print("✅ PDF split into individual pages!")

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.ssh',
#  'anaconda',
#  'anaconda3',
#  'anaconda_projects',
#  'Ankit Sir .ipynb',
#  'AppData',
#  'Application Data',
#  'BigBasket.ipynb',
#  'class test.ipynb',
#  'Contacts',
#  'Cookies',
#  'Data-driven Decision Making (D3M) - Reading Material.pdf',
#  'dataset.pdf',
#  'Documents',
#  'Downloads',
#  'EV Dataset (Project 2).ipynb',
#  'ex1.xlsx',
#  'ex2.xlsx',
#  'ExamScores.csv',
#  'Favorites',
#  'fdic_failed_bank_list.html',
#  'income.csv',
#  'income_new.csv',
#  'Links',
#  'Local Settings',
#  'merged_output.pdf',
#  'Microsoft',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'New_func.py',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{3958d2c6-9382-11f0-9678-f0bc04114819}.TM.blf',
#  'NTUSER.DAT{3958d2c6-9382-11f0-9678-f0bc04114819}.TMContainer00000000000000000001.regtrans-ms',
# ...

# %%
pdfs = ("Data-driven Decision Making (D3M) - Reading Material.pdf","ROLE PLAY.pdf")  # Replace with your file names
merge_pdfs(pdfs, "merged_output.pdf")

# %%
split_pdf("merged_output.pdf")   # Or any PDF you want to split
# Out:
# ✅ PDF split into individual pages!
